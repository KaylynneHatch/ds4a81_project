# %%
import pandas as pd

# %%
employment10 = pd.read_csv('../Original Datasets/Employment CSVs/table14full10.csv')
employment11 = pd.read_csv('../Original Datasets/Employment CSVs/table14full11.csv')
employment12 = pd.read_csv('../Original Datasets/Employment CSVs/table14full12.csv')
employment13 = pd.read_csv('../Original Datasets/Employment CSVs/table14full13.csv')
employment14 = pd.read_csv('../Original Datasets/Employment CSVs/table14full14.csv')
employment15 = pd.read_csv('../Original Datasets/Employment CSVs/table14full15.csv')
employment16 = pd.read_csv('../Original Datasets/Employment CSVs/table14full16.csv')
employment17 = pd.read_csv('../Original Datasets/Employment CSVs/table14full17.csv')
employment18 = pd.read_csv('../Original Datasets/Employment CSVs/table14full18.csv')
employment19 = pd.read_csv('../Original Datasets/Employment CSVs/table14full19.csv')

# %%
dfs = [employment10, employment11, employment12, employment13, employment14, employment15, employment16]
dfs2 = [employment17, employment18, employment19]

# %%
for df in dfs:
    df.drop(columns={'Unnamed: 11','Unnamed: 12','Unnamed: 13'},inplace=True)
    df.rename(columns={'States:  Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2010 annual averages':'State FIPS Code',
                            'Unnamed: 1':'Group Code',
                            'Unnamed: 2':'State',
                            'Unnamed: 3': 'Group',
                            'Unnamed: 4': 'Civilian non-institutional population',
                            'Unnamed: 5': 'Civilian Labor Force: Total',
                            'Unnamed: 6': 'Civilian Labor Force: Percentage',
                            'Unnamed: 7': 'Employed: Total',
                            'Unnamed: 8': 'Employed: Percentage',
                            'Unnamed: 9': 'Unemployed: Total',
                            'Unnamed: 10': 'Unemployed: Percentage'},
                   inplace=True)

# %%
for df in dfs2:
    df.drop(columns={'Unnamed: 11'},inplace=True)
    df.rename(columns={'States:  Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2010 annual averages':'State FIPS Code',
                            'Unnamed: 1':'Group Code',
                            'Unnamed: 2':'State',
                            'Unnamed: 3': 'Group',
                            'Unnamed: 4': 'Civilian non-institutional population',
                            'Unnamed: 5': 'Civilian Labor Force: Total',
                            'Unnamed: 6': 'Civilian Labor Force: Percentage',
                            'Unnamed: 7': 'Employed: Total',
                            'Unnamed: 8': 'Employed: Percentage',
                            'Unnamed: 9': 'Unemployed: Total',
                            'Unnamed: 10': 'Unemployed: Percentage'},
                   inplace=True)

# %%
all_dfs = [employment10, employment11, employment12, employment13, employment14, employment15, 
           employment16, employment17, employment18, employment19]
year = 2010

for df in all_dfs:
    df['Year'] = year
    year += 1

# %%
for df in all_dfs:
    df.drop([0,1,2,3,4,5,6], inplace=True)
    df.dropna(subset=['State'],inplace=True)

# %%
employment11
# Out:
#      States:  Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2011 annual averages  \
# 7                                                    01
# 8                                                    01
# 9                                                    01
# 10                                                   01
# 11                                                   01
# ...                                                 ...
# 2650                                                 56
# 2651                                                 56
# 2652                                                 56
# 2653                                                 56
# 2654                                                 56
#
#      Group Code    State                                         Group  \
# 7            01  Alabama                                         Total
# ...

# %%
employment10['Group'].unique()
# Out:
# array(['Total', 'Men', 'Women', 'White', 'White, men', 'White, women',
#        'Black or African American', 'Black or African American, men',
#        'Black or African American, women', 'Asian',
#        'Hispanic or Latino ethnicity',
#        'Hispanic or Latino ethnicity, men',
#        'Hispanic or Latino ethnicity, women',
#        'Married men, spouse present', 'Married women, spouse present',
#        'Women who maintain families', 'Total, 16 to 19 years',
#        'Total, 20 to 24 years', 'Total, 25 to 34 years',
#        'Total, 35 to 44 years', 'Total, 45 to 54 years',
#        'Total, 55 to 64 years', 'Total, 65 years and over',
#        'Men, 16 to 19 years', 'Men, 20 to 24 years',
#        'Men, 25 to 34 years', 'Men, 35 to 44 years',
#        'Men, 45 to 54 years', 'Men, 55 to 64 years',
#        'Men, 65 years and over', 'Women, 16 to 19 years',
#        'Women, 20 to 24 years', 'Women, 25 to 34 years',
#        'Women, 35 to 44 years', 'Women, 45 to 54 years',
# ...

# %%
mask = employment10['Group'].str.contains('16 to 19 years')
teens10 = employment10[mask]

# %%
mask = teens10['Group'].str.contains('Total')
totals10 = teens10[mask]

# %%
totals10.head()
# Out:
#     State FIPS Code Group Code       State                  Group  \
# 23               01         19     Alabama  Total, 16 to 19 years
# 70               02         19      Alaska  Total, 16 to 19 years
# 111              04         19     Arizona  Total, 16 to 19 years
# 162              05         19    Arkansas  Total, 16 to 19 years
# 213              06         19  California  Total, 16 to 19 years
#
#     Civilian non-institutional population Civilian Labor Force: Total  \
# 23                                234                          73
# 70                                 42                          18
# 111                               344                         106
# 162                               150                          54
# 213                             2,084                         585
#
#     Civilian Labor Force: Percentage Employed: Total Employed: Percentage  \
# 23                          31.4              51                 21.7
# ...

# %%
mask = employment11['Group'].str.contains('16 to 19 years')
teens11 = employment11[mask]
mask = teens11['Group'].str.contains('Total')
totals11 = teens11[mask]

# %%
mask = employment12['Group'].str.contains('16 to 19 years')
teens12 = employment12[mask]
mask = teens12['Group'].str.contains('Total')
totals12 = teens12[mask]

# %%
mask = employment13['Group'].str.contains('16 to 19 years')
teens13 = employment13[mask]
mask = teens13['Group'].str.contains('Total')
totals13 = teens13[mask]

# %%
mask = employment14['Group'].str.contains('16 to 19 years')
teens14 = employment14[mask]
mask = teens14['Group'].str.contains('Total')
totals14 = teens14[mask]

# %%
mask = employment15['Group'].str.contains('16 to 19 years')
teens15 = employment15[mask]
mask = teens15['Group'].str.contains('Total')
totals15 = teens15[mask]

# %%
mask = employment16['Group'].str.contains('16 to 19 years')
teens16 = employment16[mask]
mask = teens16['Group'].str.contains('Total')
totals16 = teens16[mask]

# %%
mask = employment17['Group'].str.contains('16 to 19 years')
teens17 = employment17[mask]
mask = teens17['Group'].str.contains('Total')
totals17 = teens17[mask]

# %%
mask = employment18['Group'].str.contains('16 to 19 years')
teens18 = employment18[mask]
mask = teens18['Group'].str.contains('Total')
totals18 = teens18[mask]

# %%
mask = employment19['Group'].str.contains('16 to 19 years')
teens19 = employment19[mask]
mask = teens19['Group'].str.contains('Total')
totals19 = teens19[mask]

# %%
totals = [totals10, totals11, totals12, totals13, totals14, totals15, totals16, totals17, totals18, totals19]

# %%
totals10[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
# Out:
#                      State Employed: Total Employed: Percentage  \
# 23                 Alabama          51                 21.7
# 70                  Alaska          14                 34.7
# 111                Arizona          73                 21.1
# 162               Arkansas          39                 26.1
# 213             California         384                 18.4
# 280               Colorado          69                 27.1
# 338            Connecticut          66                 31.6
# 398               Delaware          13                 25.0
# 456   District of Columbia           3                 11.1
# 515                Florida         183                 20.1
# 579                Georgia          88                 15.9
# 638                 Hawaii          15                 21.6
# 689                  Idaho          30                 33.7
# 739               Illinois         187                 25.8
# 801                Indiana          95                 23.1
# ...

# %%
for df in totals:
    df = df[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]

# %%
totals10 = totals10[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals11 = totals11[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals12 = totals12[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals13 = totals13[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals14 = totals14[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals15 = totals15[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals16 = totals16[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals17 = totals17[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals18 = totals18[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]
totals19 = totals19[['State','Employed: Total','Employed: Percentage','Unemployed: Total','Unemployed: Percentage','Year']]

# %%
totals19
# Out:
#                State Employed: Total Employed: Percentage Unemployed: Total  \
# 56            Alaska              13                 33.2                 2
# 96           Arizona             138                 33.6                26
# 141         Arkansas              49                 31.3                 5
# 183       California             447                 22.5                76
# 394          Florida             254                 26.6                37
# 447          Georgia             159                 27.6                17
# 520            Idaho              38                 41.0                 4
# 561         Illinois             197                 29.7                34
# 610          Indiana             140                 39.5                19
# 709         Kentucky              79                 36.0                 9
# 747        Louisiana              64                 24.8                13
# ...

# %%
others = [totals11, totals12, totals13, totals14, totals15, totals16, totals17, totals18, totals19]
merged = totals10.append(others, ignore_index=True)

# %%
merged
# Out:
#              State Employed: Total Employed: Percentage Unemployed: Total  \
# 0          Alabama          51                 21.7                23
# 1           Alaska          14                 34.7                 3
# 2          Arizona          73                 21.1                33
# 3         Arkansas          39                 26.1                15
# 4       California         384                 18.4               201
# ..             ...             ...                  ...               ...
# 441           Utah              97                 49.3                 7
# 442     Washington             103                 26.9                19
# 443  West Virginia              26                 28.2                 4
# 444      Wisconsin             148                 48.1                16
# 445        Wyoming              14                 46.4                 1
#
#     Unemployed: Percentage  Year
# 0                 30.8      2010
# ...

# %%
merged.to_csv(r'../Cleaned Datasets/teen_employment.csv', index = False, header=True)

# %%
mask = ~employment19['State'].isin(teen_states19)
employment19[mask]
# Out:
#      States: Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2019 annual averages  \
# 7                                                    01
# 8                                                    01
# 9                                                    01
# 10                                                   01
# 11                                                   01
# ...                                                 ...
# 1864                                                 51
# 1865                                                 51
# 1866                                                 51
# 1867                                                 51
# 1868                                                 51
#
#      Group Code     State                                      Group  \
# 7            02   Alabama                                        Men
# ...

# %%
mask = employment19['State'] == 'Alabama'
employment19[mask]
# Out:
#    States: Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2019 annual averages  \
# 7                                                  01
# 8                                                  01
# 9                                                  01
# 10                                                 01
# 11                                                 01
# 12                                                 01
# 13                                                 01
# 14                                                 01
# 15                                                 01
# 16                                                 01
# 17                                                 01
# 18                                                 01
# 19                                                 01
# 20                                                 01
# ...

# %%
teen_states19 = list(teens19['State'].unique())

# %%
teen_states19
# Out:
# ['Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Florida',
#  'Georgia',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Kentucky',
#  'Louisiana',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Montana',
#  'Nebraska',
#  'New York',
#  'North Carolina',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']
