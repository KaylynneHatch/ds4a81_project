# %%
import pandas as pd
import sys
import os
from functools import reduce

# %%
#Import csv files for the past 10 years

edu_2019 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2019.S1501-2021-01-15T034613.csv')

edu_2018 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2018.S1501-2021-01-15T034641.csv')

edu_2017 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2017.S1501-2021-01-15T034716.csv')

edu_2016 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2016.S1501-2021-01-15T034746.csv')

edu_2015 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2015.S1501-2021-01-15T034815.csv')

edu_2014 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2014.S1501-2021-01-15T034839.csv')

edu_2013 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2013.S1501-2021-01-15T034906.csv')

edu_2012 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2012.S1501-2021-01-15T034930.csv')

edu_2011 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2011.S1501-2021-01-15T034951.csv')

edu_2010 = pd.read_csv('/Users/kayh/Documents/DS4A/team_81_project/ds4a81_project/Original Datasets/NCEDS_Educational Attainment/ACSST1Y2010.S1501-2021-01-15T035018.csv')

edu_2011.head(20)
# Out:
#                                           Label Alabama!!Total!!Estimate  \
# 0                     Population 18 to 24 years                  485,274
# 1                Less than high school graduate                    17.7%
# 2   High school graduate (includes equivalency)                    29.1%
# 3            Some college or associate's degree                    46.3%
# 4                   Bachelor's degree or higher                     6.9%
# 5                  Population 25 years and over                3,193,078
# 6                           Less than 9th grade                     5.6%
# 7                 9th to 12th grade, no diploma                    11.7%
# 8   High school graduate (includes equivalency)                    30.9%
# 9                       Some college, no degree                    22.2%
# 10                           Associate's degree                     7.4%
# 11                            Bachelor's degree                    13.9%
# ...
