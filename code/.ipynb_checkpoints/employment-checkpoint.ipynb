# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 1.4 MB/s eta 0:00:011
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# WARNING: You are using pip version 20.3.3; however, version 21.0 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.

# %%
employment10 = pd.read_csv('../Original Datasets/Employment CSVs/table14full10.csv')

# %%
employment10
# Out:
#      States:  Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2010 annual averages  \
# 0                                                   NaN
# 1                                (Numbers in thousands)
# 2                                       State FIPS Code
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2684  2  Error ranges cannot be properly computed wh...
# 2685  3  Fewer than 500 persons or less than 0.05 pe...
# 2686    NOTE:  Data for demographic groups are not s...
# 2687  mined by the sample size. Items may not sum to...
# 2688  sented for all races. In addition, persons who...
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 3                             Unnamed: 4  \
# 0            NaN        NaN        NaN                                    NaN
# 1            NaN        NaN        NaN                                    NaN
# 2     Group Code      State      Group  Civilian non-institutional population
# 3            NaN        NaN        NaN                                    NaN
# 4            NaN        NaN        NaN                                    NaN
# ...          ...        ...        ...                                    ...
# 2684         NaN        NaN        NaN                                    NaN
# 2685         NaN        NaN        NaN                                    NaN
# 2686         NaN        NaN        NaN                                    NaN
# 2687         NaN        NaN        NaN                                    NaN
# 2688         NaN        NaN        NaN                                    NaN
#
#                 Unnamed: 5             Unnamed: 6  Unnamed: 7  \
# 0                      NaN                    NaN         NaN
# 1                      NaN                    NaN         NaN
# 2     Civilian labor force                    NaN         NaN
# 3                   Number  Percent of population  Employment
# 4                      NaN                    NaN      Number
# ...                    ...                    ...         ...
# 2684                   NaN                    NaN         NaN
# 2685                   NaN                    NaN         NaN
# 2686                   NaN                    NaN         NaN
# 2687                   NaN                    NaN         NaN
# 2688                   NaN                    NaN         NaN
#
#                  Unnamed: 8    Unnamed: 9 Unnamed: 10  Unnamed: 11  \
# 0                       NaN           NaN         NaN          NaN
# 1                       NaN           NaN         NaN          NaN
# 2                       NaN           NaN         NaN          NaN
# 3                       NaN  Unemployment         NaN          NaN
# 4     Percent of population        Number        Rate  Error range
# ...                     ...           ...         ...          ...
# 2684                    NaN           NaN         NaN          NaN
# 2685                    NaN           NaN         NaN          NaN
# 2686                    NaN           NaN         NaN          NaN
# 2687                    NaN           NaN         NaN          NaN
# 2688                    NaN           NaN         NaN          NaN
#
#      Unnamed: 12 Unnamed: 13
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 2684         NaN         NaN
# 2685         NaN         NaN
# 2686         NaN         NaN
# 2687         NaN         NaN
# 2688         NaN         NaN
#
# [2689 rows x 14 columns]

# %%
employment10 = pd.read_excel('../Original Datasets/Employment CSVs/table14full10.xls')

# %%
employment10
# Out:
#      States:  Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2010 annual averages  \
# 0                                                   NaN
# 1                                (Numbers in thousands)
# 2                                       State FIPS Code
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2684  2  Error ranges cannot be properly computed wh...
# 2685  3  Fewer than 500 persons or less than 0.05 pe...
# 2686    NOTE:  Data for demographic groups are not s...
# 2687  mined by the sample size. Items may not sum to...
# 2688  sented for all races. In addition, persons who...
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 3                             Unnamed: 4  \
# 0            NaN        NaN        NaN                                    NaN
# 1            NaN        NaN        NaN                                    NaN
# 2     Group Code      State      Group  Civilian non-institutional population
# 3            NaN        NaN        NaN                                    NaN
# 4            NaN        NaN        NaN                                    NaN
# ...          ...        ...        ...                                    ...
# 2684         NaN        NaN        NaN                                    NaN
# 2685         NaN        NaN        NaN                                    NaN
# 2686         NaN        NaN        NaN                                    NaN
# 2687         NaN        NaN        NaN                                    NaN
# 2688         NaN        NaN        NaN                                    NaN
#
#                 Unnamed: 5             Unnamed: 6  Unnamed: 7  \
# 0                      NaN                    NaN         NaN
# 1                      NaN                    NaN         NaN
# 2     Civilian labor force                    NaN         NaN
# 3                   Number  Percent of population  Employment
# 4                      NaN                    NaN      Number
# ...                    ...                    ...         ...
# 2684                   NaN                    NaN         NaN
# 2685                   NaN                    NaN         NaN
# 2686                   NaN                    NaN         NaN
# 2687                   NaN                    NaN         NaN
# 2688                   NaN                    NaN         NaN
#
#                  Unnamed: 8    Unnamed: 9 Unnamed: 10  Unnamed: 11  \
# 0                       NaN           NaN         NaN          NaN
# 1                       NaN           NaN         NaN          NaN
# 2                       NaN           NaN         NaN          NaN
# 3                       NaN  Unemployment         NaN          NaN
# 4     Percent of population        Number        Rate  Error range
# ...                     ...           ...         ...          ...
# 2684                    NaN           NaN         NaN          NaN
# 2685                    NaN           NaN         NaN          NaN
# 2686                    NaN           NaN         NaN          NaN
# 2687                    NaN           NaN         NaN          NaN
# 2688                    NaN           NaN         NaN          NaN
#
#      Unnamed: 12 Unnamed: 13
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 2684         NaN         NaN
# 2685         NaN         NaN
# 2686         NaN         NaN
# 2687         NaN         NaN
# 2688         NaN         NaN
#
# [2689 rows x 14 columns]

# %%
employment10.columns
# Out:
# Index(['States:  Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2010 annual averages',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
employment10.drop(columns={'Unnamed: 11','Unnamed: 12','Unnamed: 13'},inplace=True)

# %%
employment10.rename(columns={'States:  Employment status of the civilian noninstitutional population by sex, race, Hispanic or Latino ethnicity, marital status, and detailed age, 2010 annual averages':'State FIPS Code',
                            'Unnamed: 1':'Group Code',
                            'Unnamed: 2':'State',
                            'Unnamed: 3': 'Group',
                            'Unnamed: 4': 'Civilian non-institutional population',
                            'Unnamed: 5': 'Civilian Labor Force: Total',
                            'Unnamed: 6': 'Civilian Labor Force: Percentage',
                            'Unnamed: 7': 'Employed: Total',
                            'Unnamed: 8': 'Employed: Percentage',
                            'Unnamed: 9': 'Unemployed: Total',
                            'Unnamed: 10': 'Unemployed: Percentage'},
                   inplace=True)

# %%
employment10
# Out:
#                                         State FIPS Code  Group Code  State  \
# 0                                                   NaN         NaN    NaN
# 1                                (Numbers in thousands)         NaN    NaN
# 2                                       State FIPS Code  Group Code  State
# 3                                                   NaN         NaN    NaN
# 4                                                   NaN         NaN    NaN
# ...                                                 ...         ...    ...
# 2684  2  Error ranges cannot be properly computed wh...         NaN    NaN
# 2685  3  Fewer than 500 persons or less than 0.05 pe...         NaN    NaN
# 2686    NOTE:  Data for demographic groups are not s...         NaN    NaN
# 2687  mined by the sample size. Items may not sum to...         NaN    NaN
# 2688  sented for all races. In addition, persons who...         NaN    NaN
#
#       Group  Civilian non-institutional population  \
# 0       NaN                                    NaN
# 1       NaN                                    NaN
# 2     Group  Civilian non-institutional population
# 3       NaN                                    NaN
# 4       NaN                                    NaN
# ...     ...                                    ...
# 2684    NaN                                    NaN
# 2685    NaN                                    NaN
# 2686    NaN                                    NaN
# 2687    NaN                                    NaN
# 2688    NaN                                    NaN
#
#      Civilian Labor Force: Total Civilian Labor Force: Percentage  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2           Civilian labor force                              NaN
# 3                         Number            Percent of population
# 4                            NaN                              NaN
# ...                          ...                              ...
# 2684                         NaN                              NaN
# 2685                         NaN                              NaN
# 2686                         NaN                              NaN
# 2687                         NaN                              NaN
# 2688                         NaN                              NaN
#
#      Employed: Total   Employed: Percentage Unemployed: Total  \
# 0                NaN                    NaN               NaN
# 1                NaN                    NaN               NaN
# 2                NaN                    NaN               NaN
# 3         Employment                    NaN      Unemployment
# 4             Number  Percent of population            Number
# ...              ...                    ...               ...
# 2684             NaN                    NaN               NaN
# 2685             NaN                    NaN               NaN
# 2686             NaN                    NaN               NaN
# 2687             NaN                    NaN               NaN
# 2688             NaN                    NaN               NaN
#
#      Unemployed: Percentage
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                      Rate
# ...                     ...
# 2684                    NaN
# 2685                    NaN
# 2686                    NaN
# 2687                    NaN
# 2688                    NaN
#
# [2689 rows x 11 columns]

# %%
employment10.drop([0,1,2,3,4,5,6],inplace=True)

# %%
employment10.dropna(subset=['State'],inplace=True)

# %%
employment10['Group'].unique()
# Out:
# array(['Total', 'Men', 'Women', 'White', 'White, men', 'White, women',
#        'Black or African American', 'Black or African American, men',
#        'Black or African American, women', 'Asian',
#        'Hispanic or Latino ethnicity',
#        'Hispanic or Latino ethnicity, men',
#        'Hispanic or Latino ethnicity, women',
#        'Married men, spouse present', 'Married women, spouse present',
#        'Women who maintain families', 'Total, 16 to 19 years',
#        'Total, 20 to 24 years', 'Total, 25 to 34 years',
#        'Total, 35 to 44 years', 'Total, 45 to 54 years',
#        'Total, 55 to 64 years', 'Total, 65 years and over',
#        'Men, 16 to 19 years', 'Men, 20 to 24 years',
#        'Men, 25 to 34 years', 'Men, 35 to 44 years',
#        'Men, 45 to 54 years', 'Men, 55 to 64 years',
#        'Men, 65 years and over', 'Women, 16 to 19 years',
#        'Women, 20 to 24 years', 'Women, 25 to 34 years',
#        'Women, 35 to 44 years', 'Women, 45 to 54 years',
#        'Women, 55 to 64 years', 'Women, 65 years and over',
#        'White, 16 to 19 years', 'White, 20 to 24 years',
#        'White, 25 to 34 years', 'White, 35 to 44 years',
#        'White, 45 to 54 years', 'White, 55 to 64 years',
#        'White, 65 years and over',
#        'Black or African American, 16 to 19 years',
#        'Black or African American, 20 to 24 years',
#        'Black or African American, 25 to 34 years',
#        'Black or African American, 35 to 44 years',
#        'Black or African American, 45 to 54 years',
#        'Black or African American, 55 to 64 years',
#        'Hispanic or Latino ethnicity, 25 to 34 years', 'Asian, men',
#        'Asian, women', 'Hispanic or Latino ethnicity, 16 to 19 years',
#        'Hispanic or Latino ethnicity, 20 to 24 years',
#        'Hispanic or Latino ethnicity, 35 to 44 years',
#        'Hispanic or Latino ethnicity, 45 to 54 years',
#        'Hispanic or Latino ethnicity, 55 to 64 years',
#        'Black or African American, 65 years and over',
#        'Asian, 16 to 19 years', 'Asian, 20 to 24 years',
#        'Asian, 25 to 34 years', 'Asian, 35 to 44 years',
#        'Asian, 45 to 54 years', 'Asian, 55 to 64 years',
#        'Asian, 65 years and over',
#        'Hispanic or Latino ethnicity, 65 years and over'], dtype=object)

# %%
mask = employment10['Group'].str.contains('16 to 19 years')
teens10 = employment10[mask]

# %%
mask = teens10['Group'].str.contains('Total')
teens10[mask]
# Out:
#      State FIPS Code Group Code                 State                  Group  \
# 23                01         19               Alabama  Total, 16 to 19 years
# 70                02         19                Alaska  Total, 16 to 19 years
# 111               04         19               Arizona  Total, 16 to 19 years
# 162               05         19              Arkansas  Total, 16 to 19 years
# 213               06         19            California  Total, 16 to 19 years
# 280               08         19              Colorado  Total, 16 to 19 years
# 338               09         19           Connecticut  Total, 16 to 19 years
# 398               10         19              Delaware  Total, 16 to 19 years
# 456               11         19  District of Columbia  Total, 16 to 19 years
# 515               12         19               Florida  Total, 16 to 19 years
# 579               13         19               Georgia  Total, 16 to 19 years
# 638               15         19                Hawaii  Total, 16 to 19 years
# 689               16         19                 Idaho  Total, 16 to 19 years
# 739               17         19              Illinois  Total, 16 to 19 years
# 801               18         19               Indiana  Total, 16 to 19 years
# 853               19         19                  Iowa  Total, 16 to 19 years
# 899               20         19                Kansas  Total, 16 to 19 years
# 947               21         19              Kentucky  Total, 16 to 19 years
# 993               22         19             Louisiana  Total, 16 to 19 years
# 1037              23         19                 Maine  Total, 16 to 19 years
# 1083              24         19              Maryland  Total, 16 to 19 years
# 1145              25         19         Massachusetts  Total, 16 to 19 years
# 1202              26         19              Michigan  Total, 16 to 19 years
# 1262              27         19             Minnesota  Total, 16 to 19 years
# 1311              28         19           Mississippi  Total, 16 to 19 years
# 1361              29         19              Missouri  Total, 16 to 19 years
# 1406              30         19               Montana  Total, 16 to 19 years
# 1449              31         19              Nebraska  Total, 16 to 19 years
# 1497              32         19                Nevada  Total, 16 to 19 years
# 1556              33         19         New Hampshire  Total, 16 to 19 years
# 1602              34         19            New Jersey  Total, 16 to 19 years
# 1661              35         19            New Mexico  Total, 16 to 19 years
# 1713              36         19              New York  Total, 16 to 19 years
# 1778              37         19        North Carolina  Total, 16 to 19 years
# 1826              38         19          North Dakota  Total, 16 to 19 years
# 1872              39         19                  Ohio  Total, 16 to 19 years
# 1926              40         19              Oklahoma  Total, 16 to 19 years
# 1976              41         19                Oregon  Total, 16 to 19 years
# 2029              42         19          Pennsylvania  Total, 16 to 19 years
# 2087              44         19          Rhode Island  Total, 16 to 19 years
# 2145              45         19        South Carolina  Total, 16 to 19 years
# 2193              46         19          South Dakota  Total, 16 to 19 years
# 2239              47         19             Tennessee  Total, 16 to 19 years
# 2293              48         19                 Texas  Total, 16 to 19 years
# 2355              49         19                  Utah  Total, 16 to 19 years
# 2396              50         19               Vermont  Total, 16 to 19 years
# 2442              51         19              Virginia  Total, 16 to 19 years
# 2501              53         19            Washington  Total, 16 to 19 years
# 2551              54         19         West Virginia  Total, 16 to 19 years
# 2599              55         19             Wisconsin  Total, 16 to 19 years
# 2649              56         19               Wyoming  Total, 16 to 19 years
#
#      Civilian non-institutional population Civilian Labor Force: Total  \
# 23                                 234                          73
# 70                                  42                          18
# 111                                344                         106
# 162                                150                          54
# 213                              2,084                         585
# 280                                255                          92
# 338                                209                          84
# 398                                 53                          17
# 456                                 24                           5
# 515                                909                         266
# 579                                553                         138
# 638                                 68                          20
# 689                                 88                          40
# 739                                727                         258
# 801                                410                         131
# 853                                174                          92
# 899                                155                          76
# 947                                215                          90
# 993                                281                          88
# 1037                                73                          36
# 1083                               324                         122
# 1145                               391                         143
# 1202                               625                         255
# 1262                               262                         134
# 1311                               193                          60
# 1361                               305                         131
# 1406                                47                          18
# 1449                                96                          48
# 1497                               133                          48
# 1556                                68                          30
# 1602                               496                         147
# 1661                               104                          30
# 1713                             1,049                         298
# 1778                               518                         152
# 1826                                35                          18
# 1872                               629                         272
# 1926                               210                          80
# 1976                               186                          76
# 2029                               702                         286
# 2087                                64                          29
# 2145                               236                          77
# 2193                                46                          23
# 2239                               333                         114
# 2293                             1,404                         462
# 2355                               160                          73
# 2396                                33                          16
# 2442                               437                         161
# 2501                               327                         133
# 2551                                98                          31
# 2599                               294                         145
# 2649                                30                          15
#
#      Civilian Labor Force: Percentage Employed: Total Employed: Percentage  \
# 23                           31.4              51                 21.7
# 70                           42.8              14                 34.7
# 111                          30.9              73                 21.1
# 162                          36.3              39                 26.1
# 213                          28.1             384                 18.4
# 280                          36.3              69                 27.1
# 338                          40.5              66                 31.6
# 398                          32.5              13                 25.0
# 456                          22.2               3                 11.1
# 515                          29.3             183                 20.1
# 579                          25.0              88                 15.9
# 638                          29.4              15                 21.6
# 689                          46.0              30                 33.7
# 739                          35.6             187                 25.8
# 801                          32.0              95                 23.1
# 853                          53.0              77                 44.3
# 899                          48.7              62                 39.8
# 947                          41.8              67                 31.2
# 993                          31.2              67                 23.7
# 1037                         49.0              28                 38.4
# 1083                         37.6              94                 28.9
# 1145                         36.6             113                 28.7
# 1202                         40.8             183                 29.3
# 1262                         51.3             106                 40.5
# 1311                         31.2              40                 20.8
# 1361                         43.1             102                 33.4
# 1406                         39.3              14                 29.4
# 1449                         49.5              41                 43.0
# 1497                         36.3              32                 24.4
# 1556                         43.3              24                 35.5
# 1602                         29.7             117                 23.5
# 1661                         28.8              21                 20.5
# 1713                         28.4             223                 21.3
# 1778                         29.4             111                 21.5
# 1826                         51.8              16                 45.2
# 1872                         43.2             208                 33.0
# 1926                         37.9              62                 29.6
# 1976                         41.1              54                 29.2
# 2029                         40.7             232                 33.0
# 2087                         45.3              22                 33.5
# 2145                         32.5              52                 22.0
# 2193                         50.1              20                 43.2
# 2239                         34.2              84                 25.2
# 2293                         32.9             359                 25.6
# 2355                         45.7              58                 36.3
# 2396                         48.4              14                 41.6
# 2442                         36.8             124                 28.2
# 2501                         40.5              87                 26.7
# 2551                         31.9              23                 23.3
# 2599                         49.4             117                 39.9
# 2649                         49.5              12                 39.5
#
#      Unemployed: Total Unemployed: Percentage
# 23              23                   30.8
# 70               3                   19.0
# 111             33                   31.5
# 162             15                   28.2
# 213            201                   34.4
# 280             23                   25.3
# 338             19                   21.9
# 398              4                   23.2
# 456              3                   49.9
# 515             84                   31.4
# 579             50                   36.3
# 638              5                   26.5
# 689             11                   26.7
# 739             71                   27.6
# 801             36                   27.7
# 853             15                   16.4
# 899             14                   18.4
# 947             23                   25.4
# 993             21                   23.8
# 1037             8                   21.7
# 1083            28                   23.0
# 1145            31                   21.4
# 1202            72                   28.3
# 1262            28                   21.1
# 1311            20                   33.2
# 1361            30                   22.5
# 1406             5                   25.1
# 1449             6                   13.1
# 1497            16                   32.8
# 1556             5                   17.9
# 1602            31                   20.9
# 1661             9                   28.7
# 1713            75                   25.1
# 1778            41                   27.0
# 1826             2                   12.6
# 1872            64                   23.6
# 1926            18                   22.0
# 1976            22                   28.8
# 2029            54                   18.9
# 2087             8                   25.9
# 2145            25                   32.1
# 2193             3                   13.7
# 2239            30                   26.3
# 2293           103                   22.3
# 2355            15                   20.5
# 2396             2                   14.2
# 2442            37                   23.2
# 2501            45                   34.1
# 2551             8                   26.9
# 2599            28                   19.2
# 2649             3                   20.3
